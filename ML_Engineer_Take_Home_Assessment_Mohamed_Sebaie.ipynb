# %% [markdown]
# # Design and Train an object detector to detect objects
#
# You have to design and implement a Training Pipeline that can train, test and visualize the model using the dataset provided.
#
# ## Assignment Protocols
#
# - We expect it to take ~4 hours, with an extra 15 min for clear loom explanation(s)
#   - The assessment is timeboxed at 5 hours total in a single block. So please plan accordingly
# - You need to use Google Collaboratory to run and edit this notebook
# - You can only use Python as a programming Language
# - You cannot take help from any other person
# - You can use Google to search for references
# - You can not search on google for design-related things, like what should be loss function, or what should be model architecture.
#   - But you can use pre-trained backbones from PyTorch
# - Record a 5-10 mins of code walkthrough of the work you have done. You can use Loom Platform (https://www.loom.com) to record the video.
#   - Design Decisions
#     - Model Design which layers and activation functions you used and why
#     - Loss function, which loss functions you used and why
#     - Metrics, which metrics and why
#   - Any optimizations you have made to the codebase
#   - How you implemented resume functionality, what were the things you thought would be needed to resume training from exact same point
#   - Explain what parts of the assessment are completed and what is missing?
#   - Make sure to submit the screen recording link in the submission after you are done recording
#   - Please note that the free plan on Loom only allows for videos up to 5 minutes in length. As such, you may need to record two separate 5-minute videos.
# - [NO SUBMISSION WILL BE ACCEPTED WITHOUT]
#   - Trained best model weights
#   - Visualize Function in the Notebook
#   - Code Walk-through video
#
# ## Task Details
# Design a Training Pipeline to train a object detector with following specs or assumptions:
# - Implement & Design Model
#   - You can use any backbone
#     - Either from PyTorch (torhvision) or any resource online
#     - But you need to design head your self (head means how you will use features of the back bone and get the desired outputs)
#   - Model needs to detect one object in each image
#   - Model should output following for each image passed as input:
#     - Whether we have an object or not
#     - Where is the object?
#       - The bounding box output format should be xmin, ymin, xmax, ymax
#       - It is not necessary the model is trained to output exactly this format but the visualize function which shows output should output in this format
#     - Either the object is a cat or dog?
#     - And which specie the object belongs to? There are in total 9 species:
#       - Cat [3 species]:
#         - Abyssinian
#         - Birman
#         - Persian
#       - Dog [6 species]
#         - american_bulldog
#         - american_pit_bull_terrier
#         - basset_hound
#         - beagle
#         - chihuahua
#         - pomeranian
# - Implement Custom Dataloader
#   - This is obvious as dataset is in a unique format any predifined dataloader wont work
#   - Follow best practices of writing custom dataloaders
#   - Details of the format of the dataset are defined in the Dataset Details section below
#   - Add needed pre-processing that you think would help train a better model or would help as we are using pre-trained weights as starting point
#   - Add augmentations that you think would help train a better model
# - Implement Loss Function
#   - Design and implement a loss function that can handle all of the outputs we have
#   - You can use pytorch built-in loss functions
#   - There are many scenarios which you need to handle, which one can understand from the dataset details and the model design
# - Implement Test Function
#   - The test function should be able to run the model on the validation set and output the metrics for all the outputs of the model
#   - Select the metrics carefully, there are many scenarios which can change the selection of a metric
#   - Keep in mind there are multiple outputs, you would need a metric for each output
#   - [NOTE] You don't need to implement metrics for the bounding box output as it can take more time than provided for this assessment. But please add details of the metrics you would have implemented in your code-walk through loom video.
# - Update Resume Training Functionality using the best weights
#   - Current script does not have save best weights functionality
#   - The code should be able to resume training from exactly same point from where the training was stopped if model weights file is passed
#   - Keep in mind you can not resume training from same point by just loading weights of the model
# - Implement a visualize function [Most important, without this no submission will be accepted]
#   - The input of the function should be path of a folder with images and the weight file
#     - Also the output folder path to save outputs
#   - This function should return a dictionary of dictionaries with following details for each image:
#     - {
#         "has_object": True,
#         "cat_or_dog": "cat",
#         "specie": "persian",
#         "xmin": 10,
#         "ymin": 10,
#         "xmax": 10,
#         "ymax": 10
#     }
#   - And in case there is no object it should have 0 for bbox values, "NA" for "cat_or_dog" and "specie", and False for "has_object".
#   - Values of the returned dictionary should be like explained above and keys should be image names including the extension ".jpg" or ".jpeg"
#   - Should save output image with bounding box drawn on it, with same name input image but place in the output folder
# - Try to train the best model
#
#
# ## Dataset Details
# The dataset has in total 1041 images. Each image has a single object which is either a cat or a dog.
# - There are multiple species for both cat and dog.
# - The number of images falling in each specie is as follows:
#   - basset_hound: 93
#   - Birman: 93
#   - pomeranian: 93
#   - american_pit_bull_terrier: 93
#   - american_bulldog: 93
#   - Abyssinian: 92
#   - beagle: 93
#   - Persian: 93
#   - chihuahua: 93
#   - empty: 142
# - The dataset has two folders:
#   - images
#     - Inside images folder we have 986 images in .jpg folder
#   - labels
#     - Inside labels folder we have 899 .xml files each file with details of image labels
#     - For any image that does not have a cat or dog, there is no corresponding xml file
#
# ## Deliverable
# - Updated Colab Based Jupyter Notebook:
#   - With all the required functionality Implemented
#   - Which one can train the model without any errors
#   - One should achieve same metrics (Almost same metrics) if I run training using this collab notebook
#     - Set default values for everything accordingly in the notebook
#   - During evaluation we will just run the notebook and use the best weights the notebook saves automatically
# - Best weights you have trained
#   - We will Evaluate your weights against hold-out test we have and compare results
#   - We will use visualize function to generate outputs for each image
#   - Upload weights in an easily downloadable location like, Dropbox, Google Drive, Github, etc
# - A video code-walk through explaining your design decisions including but not limited to:
#   - Model Design which layers and activation functions you used and why
#   - Loss function, which loss functions you used and why
#   - Metrics, which metrics and why
#   - Any optimizations you have made to the codebase
#   - How you implemented resume functionality, what were the things you thought would be needed to resume training from exact same point
#
#
# ## Evaluation Criteria
#  - Design Decisions
#  - Completeness: Did you include all features?
#  - Correctness: Does the solution (all deliverables) work in sensible, thought-out ways?
#  - Maintainability: Is the code written in a clean, maintainable way?
#  - Testing: Is the solution adequately tested?
#  - Documentation: Is the codebase well-documented and has proper steps to run any of the deliverables?
#
# ## Extra Points
# - Add metrics for the Bounding Box Output
# - Any Updates in the notebook (Bugs/Implementation Mistakes etc)
#
# ## How to submit
# - Please upload the Notebook for this project to GitHub, and post a link to your repository below [repo link box, on the left of submit button].
#   - Create a new GitHub repository from scratch
#   - Add the final Colab/Jupyter notebook to the repository
# - Please upload video and your final best weights on Google Drive or any other platform, and paste the link to the folder with both video and model in the text box just above the submit button.
# - Please paste the commit Id of the latest commit of your Github Repo, which should not be later than 5 hours of time when the repo was created.
#   - Please note the submission without the commit id will not be considered.

# %% [markdown]
# # Install Required Modules

# %%
# %%capture
# !pip install bs4 lxml kaggle

# %%
import random
import torch
import numpy as np

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Running on ", device)

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
# Out:
# Running on  cuda

# %% [markdown]
# # Download Dataset from Kaggle

# %%
import os
os.environ['KAGGLE_USERNAME'] = 'bilalyousaf0014'
os.environ['KAGGLE_KEY'] = '11031bc21c5e3ec23585dbe17dc4267d'

# %%
# !kaggle datasets download -d bilalyousaf0014/ml-engineer-assessment-dataset
# Out:
# Downloading ml-engineer-assessment-dataset.zip to /content
#  98% 77.0M/78.6M [00:02<00:00, 43.3MB/s]
# 100% 78.6M/78.6M [00:02<00:00, 31.8MB/s]

# %%
# %%capture
# !unzip /content/ml-engineer-assessment-dataset.zip

# %% [markdown]
# # MODEL IMPLEMENTATION:

# %%
import os
import torch
import torch.nn as nn
import numpy as np

from torchvision.models import resnet18, ResNet18_Weights, swin_v2_s, Swin_V2_S_Weights

# %%
from torch.nn.modules.activation import Softmax
class Model(nn.Module):

    def __init__(self):
        super(Model, self).__init__()
        pretrained_model = resnet18(weights=ResNet18_Weights.DEFAULT)
        # pretrained_model = swin_v2_s(weights=Swin_V2_S_Weights.DEFAULT)
        self.backbone = nn.Sequential(*list(pretrained_model.children())[:-2])
        
        # Initialize the required Layers
        self.have_object = nn.Sequential(
           nn.Conv2d(512, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 128, kernel_size=3, padding=1),
            nn.AdaptiveAvgPool2d(output_size=1),
            nn.Flatten(),
            nn.Linear(128, 64),
            nn.ReLU(inplace=True),
            nn.Linear(64, 1),
            # nn.Sigmoid()
        )
        
        self.cat_or_dog = nn.Sequential(
            nn.Conv2d(512, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.AdaptiveAvgPool2d(output_size=1),
            nn.Flatten(),
            nn.Linear(64, 32),
            nn.ReLU(inplace=True),
            nn.Linear(32, 3),
        )
        
        self.specie = nn.Sequential(
            nn.Conv2d(512, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.AdaptiveAvgPool2d(output_size=1),
            nn.Flatten(),
            nn.Linear(64, 32),
            nn.ReLU(inplace=True),
            nn.Linear(32, 10),
        )
        
        self.bbox = nn.Sequential(
            nn.Conv2d(512, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 4, kernel_size=3, padding=1),
            nn.AdaptiveAvgPool2d(output_size=1),
            nn.Flatten()
        )
        # Initialize the required Layers

    def forward(self, input):
        out_backbone = self.backbone(input)
        
        objectness = self.have_object(out_backbone)
        # Apply sigmoid to objectness scores
        # objectness = torch.sigmoid(objectness)
        
        cat_or_dog_logits = self.cat_or_dog(out_backbone)

        specie_logits = self.specie(out_backbone)
        bbox_offsets = self.bbox(out_backbone)
        
        return {
            "bbox": bbox_offsets,
            "object": objectness,
            "cat_or_dog": cat_or_dog_logits,
            "specie": specie_logits
        }

# %% [markdown]
# # CUSTOM DATALOADER IMPLEMENTATION

# %%
train_list = list(np.load('/content/assessment_dataset/train_list.npy', allow_pickle=True).tolist())
val_list = list(np.load('/content/assessment_dataset/val_list.npy', allow_pickle=True).tolist())

# %%
len(train_list), len(val_list)
# Out:
# (832, 208)

# %%
from bs4 import BeautifulSoup
from PIL import Image
def read_xml_file(path):
    with open(path, 'r') as f:
        data = f.read()
    bs_data = BeautifulSoup(data, 'xml')
    return {
        "cat_or_dog": bs_data.find("name").text,
        "xmin": int(bs_data.find("xmin").text),
        "ymin": int(bs_data.find("ymin").text),
        "xmax": int(bs_data.find("xmax").text),
        "ymax": int(bs_data.find("ymax").text),
        "specie": "_".join(path.split(os.sep)[-1].split("_")[:-1])
    }

# %%
def remove_non_existance_imgs(images_list):
  for image_path in images_list:  
    image= None
    p= os.path.join('assessment_dataset', "images/")
    if os.path.exists(p+image_path+'.jpeg'):
      image = Image.open(p+image_path+'.jpeg').convert('RGB')
      
    if os.path.exists(p+image_path+'.jpg'):
      image = Image.open(p+image_path+'.jpg').convert('RGB')

    if os.path.exists(p+image_path+'.png'):
      image = Image.open(p+image_path+'.png').convert('RGB')

    if image==None:
        images_list.remove(image_path)
        print(f"{image_path} does not exist!")
  return

# %%
remove_non_existance_imgs(train_list)
remove_non_existance_imgs(val_list)
# Out:
# Abyssinian_124 does not exist!
# beagle_14 does not exist!
# pomeranian_11 does not exist!
# beagle_16 does not exist!
# pomeranian_13 does not exist!
# pomeranian_14 does not exist!
# american_bulldog_114 does not exist!
# Abyssinian_110 does not exist!
# pomeranian_10 does not exist!
# beagle_15 does not exist!
# basset_hound_15 does not exist!
# american_pit_bull_terrier_10 does not exist!
# pomeranian_15 does not exist!
# Persian_14 does not exist!
# Birman_15 does not exist!
# beagle_12 does not exist!
# Abyssinian_134 does not exist!
# chihuahua_10 does not exist!
# chihuahua_13 does not exist!
# american_pit_bull_terrier_12 does not exist!
# american_bulldog_102 does not exist!
# Persian_11 does not exist!
# Persian_1 does not exist!
# Abyssinian_1 does not exist!
# american_bulldog_126 does not exist!
# Birman_10 does not exist!
# Abyssinian_18 does not exist!
# Birman_13 does not exist!
# american_bulldog_15 does not exist!
# american_pit_bull_terrier_13 does not exist!
# american_bulldog_108 does not exist!
# Birman_12 does not exist!
# pomeranian_12 does not exist!
# beagle_10 does not exist!
# beagle_13 does not exist!
# Persian_10 does not exist!
# basset_hound_10 does not exist!
# chihuahua_15 does not exist!
# american_pit_bull_terrier_11 does not exist!
# Birman_11 does not exist!
# american_pit_bull_terrier_14 does not exist!
# Persian_12 does not exist!
# Persian_13 does not exist!
# chihuahua_12 does not exist!
# Birman_14 does not exist!
# Abyssinian_140 does not exist!
# basset_hound_12 does not exist!
# basset_hound_14 does not exist!
# basset_hound_11 does not exist!
# chihuahua_11 does not exist!
# chihuahua_14 does not exist!

# %%
len(train_list), len(val_list)
# Out:
# (793, 196)

# %%
label2id_specie= {'basset_hound': 0,'Birman': 1,'pomeranian': 2,'american_pit_bull_terrier': 3,'american_bulldog': 4,'Abyssinian': 5,'beagle': 6,'Persian': 7,'chihuahua': 8,'NA':9}
label2id_catDog= {'cat': 0,'dog': 1, 'NA':2}

# %%
id2label_specie = {v: k for k, v in label2id_specie.items()}
id2label_catDog = {v: k for k, v in label2id_catDog.items()}

# %%
from torch.utils.data import Dataset
import torchvision.transforms as transforms

class CustomDataset(Dataset):
    def __init__(self, dataset_path, images_list ):
        self.dataset_path = dataset_path
        self.images_list = images_list
        self.transform = transforms.Compose([transforms.Resize((224, 224)), transforms.ToTensor()])
        self.image = None

    def __len__(self):
        return len(self.images_list)

    def __getitem__(self, index):
        name = self.images_list[index].split(".")[0]
        image_path = os.path.join(self.dataset_path, "images", self.images_list[index])
        xml_path = os.path.join(self.dataset_path, "labels", name+".xml")
        if os.path.exists(image_path+'.jpeg'):
          self.image = Image.open(image_path+'.jpeg').convert('RGB')
        
        if os.path.exists(image_path+'.jpg'):
          self.image = Image.open(image_path+'.jpg').convert('RGB')

        if os.path.exists(image_path+'.png'):
          self.image = Image.open(image_path+'.png').convert('RGB')

       
        if self.transform is not None:
            image= self.image
            image = self.transform(image)

        if os.path.exists(xml_path):
            xml_data = read_xml_file(xml_path)
            cat_or_dog = 0 if xml_data['cat_or_dog'] == 'cat' else 1
            xmin = xml_data['xmin']
            ymin = xml_data['ymin']
            xmax = xml_data['xmax']
            ymax = xml_data['ymax']
            specie = label2id_specie[xml_data['specie']]
            object_=1
        else:
            cat_or_dog = 2
            xmin = 0
            ymin = 0
            xmax = 0
            ymax = 0
            specie = 9
            object_=0
        bbox = [xmin, ymin, xmax, ymax]
        return image, (object_, cat_or_dog, bbox, specie)

# %% [markdown]
# # TRAINING LOOP IMPLEMENTATION

# %% [markdown]
# ## Initializations

# %%
# %%capture
# !pip install torchmetrics

# %%
from torch.utils.data import DataLoader
import torch
import torch.nn.functional as F
from torchvision import transforms
from tqdm import tqdm

# %%
def calculate_loss(outputs, have_object_loss, specie_loss,cat_or_dog_loss,bbox_loss, labels):
    object_loss = have_object_loss(outputs["object"].squeeze(), labels["object"])
    specie_loss = specie_loss(outputs["specie"], labels["specie"])
    cat_or_dog_loss = cat_or_dog_loss(outputs["cat_or_dog"], labels["cat_or_dog"])
    bbox_loss = bbox_loss(outputs["bbox"], labels["bbox"])
    total_loss = object_loss + specie_loss + cat_or_dog_loss + bbox_loss
    return total_loss

# %%
# import our library
import torchmetrics

def train(epochs, train_list, val_list, batch_size, device, model_weights=None):

    # Initialize Model and Optimizer
    model = Model()

    if model_weights is not None:
        # Load the input weights if provided
        model.load_state_dict(torch.load(model_weights))

    model.to(device)


    # Specify different learning rates for each head
    have_object_lr = 0.01
    specie_lr = 0.001
    cat_or_dog_lr = 0.001
    bbox_lr = 0.00001

    # Define the optimizer and specify different learning rates for each head
    optimizer = torch.optim.Adam([{'params': model.have_object.parameters(), 'lr': have_object_lr},
                                  {'params': model.specie.parameters(), 'lr': specie_lr},
                                  {'params': model.cat_or_dog.parameters(), 'lr': cat_or_dog_lr},
                                  {'params': model.bbox.parameters(), 'lr': bbox_lr}])

    # Initialize Loss Functions
    have_object_loss = torch.nn.BCEWithLogitsLoss()
    specie_loss      = torch.nn.CrossEntropyLoss()
    cat_or_dog_loss  = torch.nn.CrossEntropyLoss()
    bbox_loss        = torch.nn.MSELoss()  # Not necessary you need to apply function to all coordinates together, You can have separate loss functions for all coordinates too

    training_dataset = CustomDataset("assessment_dataset/", images_list=train_list)
    training_loader = DataLoader(training_dataset, batch_size=batch_size, shuffle=True, num_workers=2)

    best_scores = {'object': 0, 'cat_or_dog': 0, 'specie': 0, 'bbox': 0}
    best_weights = None

    def train_one_epoch(epoch_index, tb_writer):
        running_loss = 0.
        last_loss = 0.

        # Here, we use enumerate(training_loader) instead of
        # iter(training_loader) so that we can track the batch
        # index and do some intra-epoch reporting
        for i, data in enumerate(training_loader):
            # Every data instance is an input + label pair
            inputs, labels = data
            inputs = inputs.to(device)

            labels= {'object':labels[0].type(torch.FloatTensor).to(device), 
                     'cat_or_dog': F.one_hot(labels[1], 3).type(torch.FloatTensor).to(device), 
                     'bbox': torch.stack(labels[2]).transpose(0, 1).type(torch.FloatTensor).to(device), 
                     'specie':F.one_hot(labels[3], 10).type(torch.FloatTensor).to(device)}
            
            optimizer.zero_grad()

            # Make predictions for this batch
            outputs = model(inputs)
     
            loss = calculate_loss(outputs, have_object_loss, specie_loss,cat_or_dog_loss,bbox_loss, labels)

            # Backpropagation and optimization
            loss.backward()
            optimizer.step()

            # Gather data and report
            running_loss += loss.item()
            if i % 49 == 0:
                last_loss = running_loss / 49  # loss per batch
                running_loss = 0.
        return last_loss

    for i in range(epochs):
        epoch_loss = train_one_epoch(i, None)
        print(f'Epoch {i} Loss: {epoch_loss}')

        torch.save(model.state_dict(), "model.pth")
        score_object, score_cat_or_dog, score_specie, MAE_bbox = test(model, val_list)
        # Print the scores
        print(f"Object Detection Score      : {score_object}")
        print(f"Cat_Dog Classification Score: {score_cat_or_dog}")
        print(f"Species Classification Score: {score_specie}")
        print(f"BoundingBox Regression MAE  : {MAE_bbox}")
        print("=======================================================================================")
        print("=======================================================================================")
        # Check if the current scores are better than the previous best scores
        if score_object > best_scores['object'] and score_cat_or_dog > best_scores['cat_or_dog'] \
                and score_specie > best_scores['specie'] and MAE_bbox < best_scores['bbox']:
            best_scores['object'] = score_object
            best_scores['cat_or_dog'] = score_cat_or_dog
            best_scores['specie'] = score_specie
            best_scores['bbox'] = MAE_bbox
            best_weights = model.state_dict().copy()  # Save a copy of the current weights

    # Save the best weights to a file
    torch.save(best_weights, "best_model.pth")

# %%
def post_process_object(x):
    return (x >= 0.5).float()

def post_process_cat_or_dog(x):
    max_prob_indices = torch.argmax(x, dim=1)
    output = torch.zeros_like(x)
    output.scatter_(1, max_prob_indices.view(-1, 1), 1)
    return output

def post_process_specie(x):
    max_prob_indices = torch.argmax(x, dim=1)
    output = torch.zeros_like(x)
    output.scatter_(1, max_prob_indices.view(-1, 1), 1)
    return output

def post_process_bbox(x):
    return x

# %%
def test(model, val_list):

    val_dataset = CustomDataset("assessment_dataset/", images_list=val_list)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=2)

    metric_object = torchmetrics.classification.BinaryAccuracy().to(device)  
    metric_cat_or_dog = torchmetrics.Accuracy(task='multiclass', num_classes=3).to(device)  
    metric_specie = torchmetrics.Accuracy(task='multiclass', num_classes=10).to(device)
    metric_bbox = torchmetrics.MeanAbsoluteError().to(device)  

    for i, data in enumerate(val_loader):
        inputs, labels = data
        inputs = inputs.to(device)

        labels= {'object':labels[0].type(torch.FloatTensor).to(device), 
                 'cat_or_dog': F.one_hot(labels[1], 3).type(torch.FloatTensor).to(device), 
                 'bbox': torch.stack(labels[2]).transpose(0, 1).type(torch.FloatTensor).to(device), 
                 'specie':F.one_hot(labels[3], 10).type(torch.FloatTensor).to(device)}

        # Make predictions for this batch
        outputs = model(inputs)
        
        # Post-process the outputs
        pred_object = post_process_object(outputs["object"].squeeze())
        pred_cat_or_dog = post_process_cat_or_dog(outputs["cat_or_dog"])
        pred_specie = post_process_specie(outputs["specie"])
        pred_bbox = post_process_bbox(outputs["bbox"])

        # Update the metrics
        metric_object.update(pred_object, labels["object"].squeeze())
        metric_cat_or_dog.update(pred_cat_or_dog, labels["cat_or_dog"])
        metric_specie.update(pred_specie, labels["specie"])
        metric_bbox.update(pred_bbox, labels["bbox"])


    score_object = metric_object.compute().item()
    score_cat_or_dog = metric_cat_or_dog.compute().item()
    score_specie = metric_specie.compute().item()
    score_bbox = metric_bbox.compute().item()

    return score_object, score_cat_or_dog, score_specie, score_bbox

# %%
# Define hyperparameters
batch_size = 128
num_epochs = 100
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
train(num_epochs,train_list, val_list, batch_size, device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 213MB/s]
# Epoch 0 Loss: 817.5804368622449
# Object Detection Score      : 0.15306122601032257
# Cat_Dog Classification Score: 0.7244898080825806
# Species Classification Score: 0.8999999761581421
# BoundingBox Regression MAE  : 142.53724670410156
# =======================================================================================
# =======================================================================================
# Epoch 1 Loss: 784.3367346938776
# Object Detection Score      : 0.8469387888908386
# Cat_Dog Classification Score: 0.8809523582458496
# Species Classification Score: 0.9428571462631226
# BoundingBox Regression MAE  : 142.40646362304688
# =======================================================================================
# =======================================================================================
# Epoch 2 Loss: 735.9742506377551
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9319728016853333
# Species Classification Score: 0.9755101799964905
# BoundingBox Regression MAE  : 142.23292541503906
# =======================================================================================
# =======================================================================================
# Epoch 3 Loss: 694.383450255102
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9625850319862366
# Species Classification Score: 0.9755101799964905
# BoundingBox Regression MAE  : 141.99530029296875
# =======================================================================================
# =======================================================================================
# Epoch 4 Loss: 816.2834821428571
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9591836929321289
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 141.67156982421875
# =======================================================================================
# =======================================================================================
# Epoch 5 Loss: 870.425462372449
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9846938848495483
# BoundingBox Regression MAE  : 141.244873046875
# =======================================================================================
# =======================================================================================
# Epoch 6 Loss: 648.9259406887755
# Object Detection Score      : 0.9642857313156128
# Cat_Dog Classification Score: 0.9523809552192688
# Species Classification Score: 0.9785714149475098
# BoundingBox Regression MAE  : 140.69070434570312
# =======================================================================================
# =======================================================================================
# Epoch 7 Loss: 753.4221141581633
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9727891087532043
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 139.97421264648438
# =======================================================================================
# =======================================================================================
# Epoch 8 Loss: 786.7293526785714
# Object Detection Score      : 0.9642857313156128
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9836734533309937
# BoundingBox Regression MAE  : 139.06900024414062
# =======================================================================================
# =======================================================================================
# Epoch 9 Loss: 948.854512117347
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 137.9547119140625
# =======================================================================================
# =======================================================================================
# Epoch 10 Loss: 666.7100605867347
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 136.60533142089844
# =======================================================================================
# =======================================================================================
# Epoch 11 Loss: 622.459941007653
# Object Detection Score      : 0.9693877696990967
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.981632649898529
# BoundingBox Regression MAE  : 134.98629760742188
# =======================================================================================
# =======================================================================================
# Epoch 12 Loss: 847.959980867347
# Object Detection Score      : 0.9693877696990967
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 133.09390258789062
# =======================================================================================
# =======================================================================================
# Epoch 13 Loss: 555.1970264668367
# Object Detection Score      : 0.9795918464660645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 130.9488525390625
# =======================================================================================
# =======================================================================================
# Epoch 14 Loss: 593.5790417729592
# Object Detection Score      : 0.9846938848495483
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9785714149475098
# BoundingBox Regression MAE  : 128.52142333984375
# =======================================================================================
# =======================================================================================
# Epoch 15 Loss: 586.6788504464286
# Object Detection Score      : 0.9795918464660645
# Cat_Dog Classification Score: 0.976190447807312
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 125.8348617553711
# =======================================================================================
# =======================================================================================
# Epoch 16 Loss: 502.42299107142856
# Object Detection Score      : 0.9642857313156128
# Cat_Dog Classification Score: 0.9795918464660645
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 122.83366394042969
# =======================================================================================
# =======================================================================================
# Epoch 17 Loss: 481.6187420280612
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 119.51688385009766
# =======================================================================================
# =======================================================================================
# Epoch 18 Loss: 507.10574776785717
# Object Detection Score      : 0.9642857313156128
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 115.99639129638672
# =======================================================================================
# =======================================================================================
# Epoch 19 Loss: 536.221022002551
# Object Detection Score      : 0.9744898080825806
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9928571581840515
# BoundingBox Regression MAE  : 112.34973907470703
# =======================================================================================
# =======================================================================================
# Epoch 20 Loss: 434.6163105867347
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9795918464660645
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 108.70221710205078
# =======================================================================================
# =======================================================================================
# Epoch 21 Loss: 388.68742028061223
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 104.96536254882812
# =======================================================================================
# =======================================================================================
# Epoch 22 Loss: 516.5635363520408
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9836734533309937
# BoundingBox Regression MAE  : 101.0750961303711
# =======================================================================================
# =======================================================================================
# Epoch 23 Loss: 309.1880978954082
# Object Detection Score      : 0.8673469424247742
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9795918464660645
# BoundingBox Regression MAE  : 97.2696304321289
# =======================================================================================
# =======================================================================================
# Epoch 24 Loss: 343.5294961734694
# Object Detection Score      : 0.8877550959587097
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 93.49593353271484
# =======================================================================================
# =======================================================================================
# Epoch 25 Loss: 495.1713966836735
# Object Detection Score      : 0.8979591727256775
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9846938848495483
# BoundingBox Regression MAE  : 89.83434295654297
# =======================================================================================
# =======================================================================================
# Epoch 26 Loss: 351.89337531887753
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.976190447807312
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 86.3431396484375
# =======================================================================================
# =======================================================================================
# Epoch 27 Loss: 248.71615911989795
# Object Detection Score      : 0.9081632494926453
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 83.40251159667969
# =======================================================================================
# =======================================================================================
# Epoch 28 Loss: 246.0022122130102
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 80.93299102783203
# =======================================================================================
# =======================================================================================
# Epoch 29 Loss: 363.3245774872449
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 78.75550079345703
# =======================================================================================
# =======================================================================================
# Epoch 30 Loss: 281.0633569834184
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9795918464660645
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 77.08007049560547
# =======================================================================================
# =======================================================================================
# Epoch 31 Loss: 219.62858737244898
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 75.79212188720703
# =======================================================================================
# =======================================================================================
# Epoch 32 Loss: 193.40190529336735
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 74.86900329589844
# =======================================================================================
# =======================================================================================
# Epoch 33 Loss: 238.27511160714286
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9795918464660645
# BoundingBox Regression MAE  : 74.21330261230469
# =======================================================================================
# =======================================================================================
# Epoch 34 Loss: 199.05187739158163
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 73.68604278564453
# =======================================================================================
# =======================================================================================
# Epoch 35 Loss: 193.23050860969389
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 73.24331665039062
# =======================================================================================
# =======================================================================================
# Epoch 36 Loss: 216.8126992984694
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 72.87779998779297
# =======================================================================================
# =======================================================================================
# Epoch 37 Loss: 186.22038424744898
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9795918464660645
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 72.60064697265625
# =======================================================================================
# =======================================================================================
# Epoch 38 Loss: 195.69513313137756
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9785714149475098
# BoundingBox Regression MAE  : 72.37882995605469
# =======================================================================================
# =======================================================================================
# Epoch 39 Loss: 209.06056680484693
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9785714149475098
# BoundingBox Regression MAE  : 72.19371032714844
# =======================================================================================
# =======================================================================================
# Epoch 40 Loss: 178.68694196428572
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 72.0254898071289
# =======================================================================================
# =======================================================================================
# Epoch 41 Loss: 244.64457110969389
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 71.88072204589844
# =======================================================================================
# =======================================================================================
# Epoch 42 Loss: 192.75007971938774
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9714285731315613
# BoundingBox Regression MAE  : 71.74159240722656
# =======================================================================================
# =======================================================================================
# Epoch 43 Loss: 168.53342235331633
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 71.55179595947266
# =======================================================================================
# =======================================================================================
# Epoch 44 Loss: 212.8254942602041
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 71.37583923339844
# =======================================================================================
# =======================================================================================
# Epoch 45 Loss: 166.80887276785714
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9806122183799744
# BoundingBox Regression MAE  : 71.1583251953125
# =======================================================================================
# =======================================================================================
# Epoch 46 Loss: 218.3828722895408
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 70.9240951538086
# =======================================================================================
# =======================================================================================
# Epoch 47 Loss: 192.47592474489795
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 70.73786926269531
# =======================================================================================
# =======================================================================================
# Epoch 48 Loss: 201.61770567602042
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 70.60494232177734
# =======================================================================================
# =======================================================================================
# Epoch 49 Loss: 203.3721301020408
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9846938848495483
# BoundingBox Regression MAE  : 70.40738677978516
# =======================================================================================
# =======================================================================================
# Epoch 50 Loss: 237.40782445790816
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 70.2558822631836
# =======================================================================================
# =======================================================================================
# Epoch 51 Loss: 168.99730947066325
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 70.05966186523438
# =======================================================================================
# =======================================================================================
# Epoch 52 Loss: 153.87889628507654
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 69.87244415283203
# =======================================================================================
# =======================================================================================
# Epoch 53 Loss: 143.65460578762756
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9795918464660645
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 69.71465301513672
# =======================================================================================
# =======================================================================================
# Epoch 54 Loss: 185.70587531887756
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 69.56060028076172
# =======================================================================================
# =======================================================================================
# Epoch 55 Loss: 178.79581871811226
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9928571581840515
# BoundingBox Regression MAE  : 69.37223052978516
# =======================================================================================
# =======================================================================================
# Epoch 56 Loss: 168.9000318877551
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 69.16297912597656
# =======================================================================================
# =======================================================================================
# Epoch 57 Loss: 163.5319375797194
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 68.9914779663086
# =======================================================================================
# =======================================================================================
# Epoch 58 Loss: 291.5740194515306
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9836734533309937
# BoundingBox Regression MAE  : 68.77742004394531
# =======================================================================================
# =======================================================================================
# Epoch 59 Loss: 195.9195631377551
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9785714149475098
# BoundingBox Regression MAE  : 68.62956237792969
# =======================================================================================
# =======================================================================================
# Epoch 60 Loss: 156.93526785714286
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 68.4758529663086
# =======================================================================================
# =======================================================================================
# Epoch 61 Loss: 171.0599290497449
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 68.30796813964844
# =======================================================================================
# =======================================================================================
# Epoch 62 Loss: 325.28569435586735
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9928571581840515
# BoundingBox Regression MAE  : 68.13566589355469
# =======================================================================================
# =======================================================================================
# Epoch 63 Loss: 250.98989556760205
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 67.87029266357422
# =======================================================================================
# =======================================================================================
# Epoch 64 Loss: 168.73254145408163
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 67.55409240722656
# =======================================================================================
# =======================================================================================
# Epoch 65 Loss: 165.17179528061226
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 67.3095474243164
# =======================================================================================
# =======================================================================================
# Epoch 66 Loss: 162.07768654336735
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9928571581840515
# BoundingBox Regression MAE  : 67.11231231689453
# =======================================================================================
# =======================================================================================
# Epoch 67 Loss: 167.2351522640306
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9938775300979614
# BoundingBox Regression MAE  : 66.9527587890625
# =======================================================================================
# =======================================================================================
# Epoch 68 Loss: 177.0633769132653
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 66.78596496582031
# =======================================================================================
# =======================================================================================
# Epoch 69 Loss: 174.60949457908163
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 66.57404327392578
# =======================================================================================
# =======================================================================================
# Epoch 70 Loss: 145.58946508290816
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 66.31591033935547
# =======================================================================================
# =======================================================================================
# Epoch 71 Loss: 268.3154296875
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 66.1142349243164
# =======================================================================================
# =======================================================================================
# Epoch 72 Loss: 164.8317323022959
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 65.8574447631836
# =======================================================================================
# =======================================================================================
# Epoch 73 Loss: 221.4358059630102
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9928571581840515
# BoundingBox Regression MAE  : 65.5571060180664
# =======================================================================================
# =======================================================================================
# Epoch 74 Loss: 140.26022401147958
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 65.34833526611328
# =======================================================================================
# =======================================================================================
# Epoch 75 Loss: 173.697265625
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 65.13409423828125
# =======================================================================================
# =======================================================================================
# Epoch 76 Loss: 149.01264548788265
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9928571581840515
# BoundingBox Regression MAE  : 64.84162902832031
# =======================================================================================
# =======================================================================================
# Epoch 77 Loss: 121.52510164221938
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 64.58940887451172
# =======================================================================================
# =======================================================================================
# Epoch 78 Loss: 165.55298349808675
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9948979616165161
# BoundingBox Regression MAE  : 64.34224700927734
# =======================================================================================
# =======================================================================================
# Epoch 79 Loss: 213.73003029336735
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9938775300979614
# BoundingBox Regression MAE  : 64.04286193847656
# =======================================================================================
# =======================================================================================
# Epoch 80 Loss: 194.20856584821428
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9928571581840515
# BoundingBox Regression MAE  : 63.77815246582031
# =======================================================================================
# =======================================================================================
# Epoch 81 Loss: 143.62061543367346
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 63.53266143798828
# =======================================================================================
# =======================================================================================
# Epoch 82 Loss: 169.4698262117347
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 63.26689147949219
# =======================================================================================
# =======================================================================================
# Epoch 83 Loss: 138.43999123086735
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9659863710403442
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 63.033111572265625
# =======================================================================================
# =======================================================================================
# Epoch 84 Loss: 240.42139668367346
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.976190447807312
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 62.80258560180664
# =======================================================================================
# =======================================================================================
# Epoch 85 Loss: 200.71390704719389
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 62.56254959106445
# =======================================================================================
# =======================================================================================
# Epoch 86 Loss: 229.04444355867346
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 62.272987365722656
# =======================================================================================
# =======================================================================================
# Epoch 87 Loss: 116.2510064572704
# Object Detection Score      : 0.9336734414100647
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 61.961326599121094
# =======================================================================================
# =======================================================================================
# Epoch 88 Loss: 121.4107740752551
# Object Detection Score      : 0.9336734414100647
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9826530814170837
# BoundingBox Regression MAE  : 61.711578369140625
# =======================================================================================
# =======================================================================================
# Epoch 89 Loss: 224.34907126913265
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 61.48258972167969
# =======================================================================================
# =======================================================================================
# Epoch 90 Loss: 185.46338887117346
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 61.185340881347656
# =======================================================================================
# =======================================================================================
# Epoch 91 Loss: 126.94299067283163
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 60.942142486572266
# =======================================================================================
# =======================================================================================
# Epoch 92 Loss: 147.37051578443877
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 60.7606315612793
# =======================================================================================
# =======================================================================================
# Epoch 93 Loss: 117.9183274872449
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 60.612274169921875
# =======================================================================================
# =======================================================================================
# Epoch 94 Loss: 116.36049107142857
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 60.31626510620117
# =======================================================================================
# =======================================================================================
# Epoch 95 Loss: 144.3766242825255
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 60.09746551513672
# =======================================================================================
# =======================================================================================
# Epoch 96 Loss: 222.94419642857142
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9795918464660645
# BoundingBox Regression MAE  : 59.797767639160156
# =======================================================================================
# =======================================================================================
# Epoch 97 Loss: 177.13570232780611
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 59.52959442138672
# =======================================================================================
# =======================================================================================
# Epoch 98 Loss: 165.30897241709184
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 59.24150848388672
# =======================================================================================
# =======================================================================================
# Epoch 99 Loss: 152.84294284119898
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9836734533309937
# BoundingBox Regression MAE  : 59.06666564941406
# =======================================================================================
# =======================================================================================

# %%
# %cp /content/best_model.pth /content/First_One

# %%
train(num_epochs,train_list, val_list, batch_size, device,'model.pth')
# Out:
# Epoch 0 Loss: 103.75775271045919
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9826530814170837
# BoundingBox Regression MAE  : 54.649654388427734
# =======================================================================================
# =======================================================================================
# Epoch 1 Loss: 89.44648836096938
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.976190447807312
# Species Classification Score: 0.9826530814170837
# BoundingBox Regression MAE  : 55.08298873901367
# =======================================================================================
# =======================================================================================
# Epoch 2 Loss: 109.94946787308673
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9755101799964905
# BoundingBox Regression MAE  : 55.0473518371582
# =======================================================================================
# =======================================================================================
# Epoch 3 Loss: 88.72417091836735
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9693877696990967
# Species Classification Score: 0.9795918464660645
# BoundingBox Regression MAE  : 55.04399108886719
# =======================================================================================
# =======================================================================================
# Epoch 4 Loss: 107.43577606823979
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9846938848495483
# BoundingBox Regression MAE  : 54.921180725097656
# =======================================================================================
# =======================================================================================
# Epoch 5 Loss: 90.05452806122449
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 54.738651275634766
# =======================================================================================
# =======================================================================================
# Epoch 6 Loss: 88.33473174426021
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.981632649898529
# BoundingBox Regression MAE  : 54.405113220214844
# =======================================================================================
# =======================================================================================
# Epoch 7 Loss: 157.89489995216837
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 54.08579635620117
# =======================================================================================
# =======================================================================================
# Epoch 8 Loss: 99.5843431122449
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 54.12967300415039
# =======================================================================================
# =======================================================================================
# Epoch 9 Loss: 79.2689283721301
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9826530814170837
# BoundingBox Regression MAE  : 54.365272521972656
# =======================================================================================
# =======================================================================================
# Epoch 10 Loss: 84.49828603316327
# Object Detection Score      : 0.9336734414100647
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9826530814170837
# BoundingBox Regression MAE  : 54.275909423828125
# =======================================================================================
# =======================================================================================
# Epoch 11 Loss: 132.58307756696428
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 54.29360580444336
# =======================================================================================
# =======================================================================================
# Epoch 12 Loss: 83.892578125
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9846938848495483
# BoundingBox Regression MAE  : 53.96205520629883
# =======================================================================================
# =======================================================================================
# Epoch 13 Loss: 96.50877909757654
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 54.148807525634766
# =======================================================================================
# =======================================================================================
# Epoch 14 Loss: 92.28117028061224
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 54.105857849121094
# =======================================================================================
# =======================================================================================
# Epoch 15 Loss: 87.33960459183673
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9846938848495483
# BoundingBox Regression MAE  : 54.24406433105469
# =======================================================================================
# =======================================================================================
# Epoch 16 Loss: 105.78939134247449
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9836734533309937
# BoundingBox Regression MAE  : 54.073936462402344
# =======================================================================================
# =======================================================================================
# Epoch 17 Loss: 103.52564971301021
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 53.756954193115234
# =======================================================================================
# =======================================================================================
# Epoch 18 Loss: 83.20750956632654
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 53.606563568115234
# =======================================================================================
# =======================================================================================
# Epoch 19 Loss: 124.34464684311224
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9795918464660645
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 53.66144561767578
# =======================================================================================
# =======================================================================================
# Epoch 20 Loss: 108.02752311862245
# Object Detection Score      : 0.9336734414100647
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 53.65031433105469
# =======================================================================================
# =======================================================================================
# Epoch 21 Loss: 74.98854033801021
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 53.31572341918945
# =======================================================================================
# =======================================================================================
# Epoch 22 Loss: 96.1363600127551
# Object Detection Score      : 0.9234693646430969
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9765306115150452
# BoundingBox Regression MAE  : 53.27052688598633
# =======================================================================================
# =======================================================================================
# Epoch 23 Loss: 81.43340441645408
# Object Detection Score      : 0.9285714030265808
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 53.27275848388672
# =======================================================================================
# =======================================================================================
# Epoch 24 Loss: 148.5331034757653
# Object Detection Score      : 0.9285714030265808
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9826530814170837
# BoundingBox Regression MAE  : 53.63105392456055
# =======================================================================================
# =======================================================================================
# Epoch 25 Loss: 147.7603136957908
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9795918464660645
# Species Classification Score: 0.9846938848495483
# BoundingBox Regression MAE  : 53.600868225097656
# =======================================================================================
# =======================================================================================
# Epoch 26 Loss: 112.86835339604592
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 53.5589485168457
# =======================================================================================
# =======================================================================================
# Epoch 27 Loss: 153.75255102040816
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9795918464660645
# Species Classification Score: 0.981632649898529
# BoundingBox Regression MAE  : 53.41318893432617
# =======================================================================================
# =======================================================================================
# Epoch 28 Loss: 169.69513313137756
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9693877696990967
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 53.07245635986328
# =======================================================================================
# =======================================================================================
# Epoch 29 Loss: 182.1930006377551
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9836734533309937
# BoundingBox Regression MAE  : 52.81507110595703
# =======================================================================================
# =======================================================================================
# Epoch 30 Loss: 92.89945392219387
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9836734533309937
# BoundingBox Regression MAE  : 52.84914016723633
# =======================================================================================
# =======================================================================================
# Epoch 31 Loss: 121.79893773915816
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9785714149475098
# BoundingBox Regression MAE  : 53.085784912109375
# =======================================================================================
# =======================================================================================
# Epoch 32 Loss: 88.51745854591837
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9836734533309937
# BoundingBox Regression MAE  : 53.212337493896484
# =======================================================================================
# =======================================================================================
# Epoch 33 Loss: 147.70616430165816
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 53.01445770263672
# =======================================================================================
# =======================================================================================
# Epoch 34 Loss: 85.2949517697704
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 52.634098052978516
# =======================================================================================
# =======================================================================================
# Epoch 35 Loss: 91.02325813137755
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9795918464660645
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 52.378089904785156
# =======================================================================================
# =======================================================================================
# Epoch 36 Loss: 161.54118502869898
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 52.24360275268555
# =======================================================================================
# =======================================================================================
# Epoch 37 Loss: 158.54478236607142
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9744898080825806
# BoundingBox Regression MAE  : 52.28712463378906
# =======================================================================================
# =======================================================================================
# Epoch 38 Loss: 138.70223812181123
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.976190447807312
# Species Classification Score: 0.9836734533309937
# BoundingBox Regression MAE  : 52.40135192871094
# =======================================================================================
# =======================================================================================
# Epoch 39 Loss: 89.87337571747449
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.976190447807312
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 52.655181884765625
# =======================================================================================
# =======================================================================================
# Epoch 40 Loss: 79.87280771683673
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 52.58590316772461
# =======================================================================================
# =======================================================================================
# Epoch 41 Loss: 94.49683115433673
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9795918464660645
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 52.470054626464844
# =======================================================================================
# =======================================================================================
# Epoch 42 Loss: 157.31983418367346
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 52.358158111572266
# =======================================================================================
# =======================================================================================
# Epoch 43 Loss: 180.09016262755102
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 52.31210708618164
# =======================================================================================
# =======================================================================================
# Epoch 44 Loss: 115.01173867984694
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 52.28723907470703
# =======================================================================================
# =======================================================================================
# Epoch 45 Loss: 87.89577686543367
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 52.19767761230469
# =======================================================================================
# =======================================================================================
# Epoch 46 Loss: 90.0758131377551
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 52.40395736694336
# =======================================================================================
# =======================================================================================
# Epoch 47 Loss: 200.0079121492347
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 52.33964920043945
# =======================================================================================
# =======================================================================================
# Epoch 48 Loss: 97.25301937181122
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 52.28738021850586
# =======================================================================================
# =======================================================================================
# Epoch 49 Loss: 73.27759785554846
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 52.34401321411133
# =======================================================================================
# =======================================================================================
# Epoch 50 Loss: 74.86602160395408
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.976190447807312
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 52.37604522705078
# =======================================================================================
# =======================================================================================
# Epoch 51 Loss: 91.64575693558673
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 52.21846008300781
# =======================================================================================
# =======================================================================================
# Epoch 52 Loss: 76.67321528220663
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9795918464660645
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 52.03171920776367
# =======================================================================================
# =======================================================================================
# Epoch 53 Loss: 109.86522441007654
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9928571581840515
# BoundingBox Regression MAE  : 51.95512771606445
# =======================================================================================
# =======================================================================================
# Epoch 54 Loss: 79.12727698501276
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 51.90549850463867
# =======================================================================================
# =======================================================================================
# Epoch 55 Loss: 114.61696827168367
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 51.95781707763672
# =======================================================================================
# =======================================================================================
# Epoch 56 Loss: 75.5291822783801
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9938775300979614
# BoundingBox Regression MAE  : 51.78352737426758
# =======================================================================================
# =======================================================================================
# Epoch 57 Loss: 89.17354910714286
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 52.0429801940918
# =======================================================================================
# =======================================================================================
# Epoch 58 Loss: 144.84628109056123
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 52.239105224609375
# =======================================================================================
# =======================================================================================
# Epoch 59 Loss: 170.8973612882653
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 52.00076675415039
# =======================================================================================
# =======================================================================================
# Epoch 60 Loss: 81.22044403698979
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 51.77680587768555
# =======================================================================================
# =======================================================================================
# Epoch 61 Loss: 139.45944276147958
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 51.75326919555664
# =======================================================================================
# =======================================================================================
# Epoch 62 Loss: 135.18120216836735
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 52.097721099853516
# =======================================================================================
# =======================================================================================
# Epoch 63 Loss: 79.78494698660714
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 52.04804611206055
# =======================================================================================
# =======================================================================================
# Epoch 64 Loss: 146.45912388392858
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 51.864097595214844
# =======================================================================================
# =======================================================================================
# Epoch 65 Loss: 87.72493821747449
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9806122183799744
# BoundingBox Regression MAE  : 51.66809844970703
# =======================================================================================
# =======================================================================================
# Epoch 66 Loss: 85.25415537308673
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 51.83930587768555
# =======================================================================================
# =======================================================================================
# Epoch 67 Loss: 218.54886798469389
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 51.937538146972656
# =======================================================================================
# =======================================================================================
# Epoch 68 Loss: 71.22406130420919
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9846938848495483
# BoundingBox Regression MAE  : 51.798011779785156
# =======================================================================================
# =======================================================================================
# Epoch 69 Loss: 201.01072225765307
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 51.58439254760742
# =======================================================================================
# =======================================================================================
# Epoch 70 Loss: 119.29753268494898
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 51.600303649902344
# =======================================================================================
# =======================================================================================
# Epoch 71 Loss: 70.46720045440051
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 51.43547821044922
# =======================================================================================
# =======================================================================================
# Epoch 72 Loss: 99.3818060427296
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 51.42343521118164
# =======================================================================================
# =======================================================================================
# Epoch 73 Loss: 89.15689772002551
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 51.42243957519531
# =======================================================================================
# =======================================================================================
# Epoch 74 Loss: 93.60893654336735
# Object Detection Score      : 0.8979591727256775
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 51.5312614440918
# =======================================================================================
# =======================================================================================
# Epoch 75 Loss: 100.20563616071429
# Object Detection Score      : 0.9132652878761292
# Cat_Dog Classification Score: 0.976190447807312
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 51.71791458129883
# =======================================================================================
# =======================================================================================
# Epoch 76 Loss: 87.95769889987245
# Object Detection Score      : 0.9030612111091614
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 51.67168426513672
# =======================================================================================
# =======================================================================================
# Epoch 77 Loss: 106.93132174744898
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 51.5840950012207
# =======================================================================================
# =======================================================================================
# Epoch 78 Loss: 167.0142598054847
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 51.629432678222656
# =======================================================================================
# =======================================================================================
# Epoch 79 Loss: 181.1826171875
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 51.706512451171875
# =======================================================================================
# =======================================================================================
# Epoch 80 Loss: 67.92731584821429
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 51.753746032714844
# =======================================================================================
# =======================================================================================
# Epoch 81 Loss: 69.35430285395408
# Object Detection Score      : 0.9132652878761292
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 51.77165222167969
# =======================================================================================
# =======================================================================================
# Epoch 82 Loss: 108.06532007334184
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 51.864044189453125
# =======================================================================================
# =======================================================================================
# Epoch 83 Loss: 79.2098313934949
# Object Detection Score      : 0.918367326259613
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9785714149475098
# BoundingBox Regression MAE  : 51.73126983642578
# =======================================================================================
# =======================================================================================
# Epoch 84 Loss: 121.12799944196429
# Object Detection Score      : 0.9336734414100647
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9734693765640259
# BoundingBox Regression MAE  : 51.296146392822266
# =======================================================================================
# =======================================================================================
# Epoch 85 Loss: 76.06337193080357
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 51.05540466308594
# =======================================================================================
# =======================================================================================
# Epoch 86 Loss: 79.94232800542092
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 50.888832092285156
# =======================================================================================
# =======================================================================================
# Epoch 87 Loss: 81.9893873565051
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 50.989566802978516
# =======================================================================================
# =======================================================================================
# Epoch 88 Loss: 89.73566047512755
# Object Detection Score      : 0.9336734414100647
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 51.243831634521484
# =======================================================================================
# =======================================================================================
# Epoch 89 Loss: 116.67013113839286
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 51.26540756225586
# =======================================================================================
# =======================================================================================
# Epoch 90 Loss: 139.73639787946428
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 51.03533172607422
# =======================================================================================
# =======================================================================================
# Epoch 91 Loss: 89.81691446109694
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 50.936866760253906
# =======================================================================================
# =======================================================================================
# Epoch 92 Loss: 82.14047552614795
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9846938848495483
# BoundingBox Regression MAE  : 50.75506591796875
# =======================================================================================
# =======================================================================================
# Epoch 93 Loss: 134.77075693558675
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 50.83608627319336
# =======================================================================================
# =======================================================================================
# Epoch 94 Loss: 69.48189871651786
# Object Detection Score      : 0.9132652878761292
# Cat_Dog Classification Score: 0.9795918464660645
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 51.289920806884766
# =======================================================================================
# =======================================================================================
# Epoch 95 Loss: 71.75057796556122
# Object Detection Score      : 0.9285714030265808
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 51.47475051879883
# =======================================================================================
# =======================================================================================
# Epoch 96 Loss: 78.47707569355867
# Object Detection Score      : 0.9285714030265808
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9836734533309937
# BoundingBox Regression MAE  : 51.257144927978516
# =======================================================================================
# =======================================================================================
# Epoch 97 Loss: 87.23687619579081
# Object Detection Score      : 0.9336734414100647
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 50.8403434753418
# =======================================================================================
# =======================================================================================
# Epoch 98 Loss: 69.12916035554846
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9523809552192688
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 50.830535888671875
# =======================================================================================
# =======================================================================================
# Epoch 99 Loss: 77.00529137436224
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 50.82096862792969
# =======================================================================================
# =======================================================================================

# %%
# %cp /content/model.pth /content/Second

# %%
train(num_epochs,train_list, val_list, batch_size, device,'model.pth')
# Out:
# Epoch 0 Loss: 110.06624681122449
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9727891087532043
# Species Classification Score: 0.9785714149475098
# BoundingBox Regression MAE  : 50.81837463378906
# =======================================================================================
# =======================================================================================
# Epoch 1 Loss: 88.05930125956633
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9625850319862366
# Species Classification Score: 0.9836734533309937
# BoundingBox Regression MAE  : 50.87336730957031
# =======================================================================================
# =======================================================================================
# Epoch 2 Loss: 82.7254563934949
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.981632649898529
# BoundingBox Regression MAE  : 50.847530364990234
# =======================================================================================
# =======================================================================================
# Epoch 3 Loss: 102.25031887755102
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9755101799964905
# BoundingBox Regression MAE  : 50.65457534790039
# =======================================================================================
# =======================================================================================
# Epoch 4 Loss: 78.25902822066327
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9826530814170837
# BoundingBox Regression MAE  : 50.62130355834961
# =======================================================================================
# =======================================================================================
# Epoch 5 Loss: 151.78298389668367
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9795918464660645
# Species Classification Score: 0.9846938848495483
# BoundingBox Regression MAE  : 50.58913803100586
# =======================================================================================
# =======================================================================================
# Epoch 6 Loss: 72.19017059948979
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9846938848495483
# BoundingBox Regression MAE  : 50.833614349365234
# =======================================================================================
# =======================================================================================
# Epoch 7 Loss: 72.51366689253827
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 50.814632415771484
# =======================================================================================
# =======================================================================================
# Epoch 8 Loss: 70.48316924426021
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9625850319862366
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 50.58222198486328
# =======================================================================================
# =======================================================================================
# Epoch 9 Loss: 97.26742865114795
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9625850319862366
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 50.44041442871094
# =======================================================================================
# =======================================================================================
# Epoch 10 Loss: 81.5272142059949
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 50.70917510986328
# =======================================================================================
# =======================================================================================
# Epoch 11 Loss: 64.10685885682398
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 50.92523193359375
# =======================================================================================
# =======================================================================================
# Epoch 12 Loss: 84.08724290497449
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9846938848495483
# BoundingBox Regression MAE  : 50.71984100341797
# =======================================================================================
# =======================================================================================
# Epoch 13 Loss: 123.88449657206633
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9727891087532043
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 50.58964920043945
# =======================================================================================
# =======================================================================================
# Epoch 14 Loss: 69.96356325733419
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9836734533309937
# BoundingBox Regression MAE  : 50.73829650878906
# =======================================================================================
# =======================================================================================
# Epoch 15 Loss: 72.15317083864795
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9836734533309937
# BoundingBox Regression MAE  : 50.936641693115234
# =======================================================================================
# =======================================================================================
# Epoch 16 Loss: 141.1311184630102
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.976190447807312
# Species Classification Score: 0.9826530814170837
# BoundingBox Regression MAE  : 50.6244010925293
# =======================================================================================
# =======================================================================================
# Epoch 17 Loss: 82.57916135204081
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9846938848495483
# BoundingBox Regression MAE  : 50.36139678955078
# =======================================================================================
# =======================================================================================
# Epoch 18 Loss: 68.43010104432398
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 50.505531311035156
# =======================================================================================
# =======================================================================================
# Epoch 19 Loss: 95.64728156887755
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 50.732749938964844
# =======================================================================================
# =======================================================================================
# Epoch 20 Loss: 118.16668327487245
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9846938848495483
# BoundingBox Regression MAE  : 50.453861236572266
# =======================================================================================
# =======================================================================================
# Epoch 21 Loss: 62.31427375637755
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.976190447807312
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 50.22282409667969
# =======================================================================================
# =======================================================================================
# Epoch 22 Loss: 140.47848573022958
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 50.25908660888672
# =======================================================================================
# =======================================================================================
# Epoch 23 Loss: 114.70102240114795
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 50.531646728515625
# =======================================================================================
# =======================================================================================
# Epoch 24 Loss: 84.16471022002551
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 50.666839599609375
# =======================================================================================
# =======================================================================================
# Epoch 25 Loss: 86.37033641581633
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 50.74629211425781
# =======================================================================================
# =======================================================================================
# Epoch 26 Loss: 82.51632254464286
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 50.47286605834961
# =======================================================================================
# =======================================================================================
# Epoch 27 Loss: 70.96774852519133
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 50.40254211425781
# =======================================================================================
# =======================================================================================
# Epoch 28 Loss: 78.73974111128827
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 50.208892822265625
# =======================================================================================
# =======================================================================================
# Epoch 29 Loss: 137.53118024553572
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 50.06952667236328
# =======================================================================================
# =======================================================================================
# Epoch 30 Loss: 77.1397480867347
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 50.21651840209961
# =======================================================================================
# =======================================================================================
# Epoch 31 Loss: 84.65008171237245
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 50.27330780029297
# =======================================================================================
# =======================================================================================
# Epoch 32 Loss: 130.97176937181123
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 50.17240905761719
# =======================================================================================
# =======================================================================================
# Epoch 33 Loss: 117.0146783322704
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 50.36753463745117
# =======================================================================================
# =======================================================================================
# Epoch 34 Loss: 81.91499422034438
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.976190447807312
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 50.35700225830078
# =======================================================================================
# =======================================================================================
# Epoch 35 Loss: 85.54760243941327
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9557822942733765
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 50.14426803588867
# =======================================================================================
# =======================================================================================
# Epoch 36 Loss: 89.30082110969387
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 50.0374870300293
# =======================================================================================
# =======================================================================================
# Epoch 37 Loss: 91.40248325892857
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 50.00244140625
# =======================================================================================
# =======================================================================================
# Epoch 38 Loss: 86.23226243622449
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 50.11153793334961
# =======================================================================================
# =======================================================================================
# Epoch 39 Loss: 69.64527861926021
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 50.109535217285156
# =======================================================================================
# =======================================================================================
# Epoch 40 Loss: 69.50357740752551
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 50.241878509521484
# =======================================================================================
# =======================================================================================
# Epoch 41 Loss: 91.64671356823979
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 50.123252868652344
# =======================================================================================
# =======================================================================================
# Epoch 42 Loss: 83.75826092155613
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 50.065887451171875
# =======================================================================================
# =======================================================================================
# Epoch 43 Loss: 87.1917948820153
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 50.02375030517578
# =======================================================================================
# =======================================================================================
# Epoch 44 Loss: 76.75502232142857
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 50.05201721191406
# =======================================================================================
# =======================================================================================
# Epoch 45 Loss: 69.61218510841837
# Object Detection Score      : 0.9642857313156128
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 50.11446762084961
# =======================================================================================
# =======================================================================================
# Epoch 46 Loss: 154.39631497130102
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 49.9504280090332
# =======================================================================================
# =======================================================================================
# Epoch 47 Loss: 92.708984375
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 49.74036407470703
# =======================================================================================
# =======================================================================================
# Epoch 48 Loss: 135.08117426658163
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 49.88189697265625
# =======================================================================================
# =======================================================================================
# Epoch 49 Loss: 81.47006038743622
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 50.11064910888672
# =======================================================================================
# =======================================================================================
# Epoch 50 Loss: 169.11286272321428
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 49.80830383300781
# =======================================================================================
# =======================================================================================
# Epoch 51 Loss: 76.80414441167092
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 49.754573822021484
# =======================================================================================
# =======================================================================================
# Epoch 52 Loss: 52.309361049107146
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 49.76934814453125
# =======================================================================================
# =======================================================================================
# Epoch 53 Loss: 142.60879703443877
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 49.96659851074219
# =======================================================================================
# =======================================================================================
# Epoch 54 Loss: 77.15852200255102
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 50.07524108886719
# =======================================================================================
# =======================================================================================
# Epoch 55 Loss: 79.10396404655613
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 50.195106506347656
# =======================================================================================
# =======================================================================================
# Epoch 56 Loss: 132.29296875
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9659863710403442
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 50.10768127441406
# =======================================================================================
# =======================================================================================
# Epoch 57 Loss: 84.77103595344387
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 49.764976501464844
# =======================================================================================
# =======================================================================================
# Epoch 58 Loss: 77.60734215561224
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 49.737693786621094
# =======================================================================================
# =======================================================================================
# Epoch 59 Loss: 81.0491021603954
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 49.67779541015625
# =======================================================================================
# =======================================================================================
# Epoch 60 Loss: 134.28579400510205
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 49.735233306884766
# =======================================================================================
# =======================================================================================
# Epoch 61 Loss: 81.26892338966837
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 49.589393615722656
# =======================================================================================
# =======================================================================================
# Epoch 62 Loss: 147.27898796237244
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 49.4942512512207
# =======================================================================================
# =======================================================================================
# Epoch 63 Loss: 85.8232720822704
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 49.760337829589844
# =======================================================================================
# =======================================================================================
# Epoch 64 Loss: 77.19803790656887
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 49.979530334472656
# =======================================================================================
# =======================================================================================
# Epoch 65 Loss: 102.83698381696429
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 49.767887115478516
# =======================================================================================
# =======================================================================================
# Epoch 66 Loss: 73.22429049744898
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9846938848495483
# BoundingBox Regression MAE  : 49.54231262207031
# =======================================================================================
# =======================================================================================
# Epoch 67 Loss: 81.50579958545919
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 49.57548904418945
# =======================================================================================
# =======================================================================================
# Epoch 68 Loss: 114.0997389190051
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9826530814170837
# BoundingBox Regression MAE  : 49.90190124511719
# =======================================================================================
# =======================================================================================
# Epoch 69 Loss: 123.91469029017857
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 49.9183235168457
# =======================================================================================
# =======================================================================================
# Epoch 70 Loss: 135.63918008609693
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9846938848495483
# BoundingBox Regression MAE  : 49.48879623413086
# =======================================================================================
# =======================================================================================
# Epoch 71 Loss: 81.66296137595663
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.981632649898529
# BoundingBox Regression MAE  : 49.57672119140625
# =======================================================================================
# =======================================================================================
# Epoch 72 Loss: 76.68300083705357
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9836734533309937
# BoundingBox Regression MAE  : 49.711822509765625
# =======================================================================================
# =======================================================================================
# Epoch 73 Loss: 134.1527323820153
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9846938848495483
# BoundingBox Regression MAE  : 49.64636993408203
# =======================================================================================
# =======================================================================================
# Epoch 74 Loss: 65.26540577168367
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 49.527915954589844
# =======================================================================================
# =======================================================================================
# Epoch 75 Loss: 73.12975825095663
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9846938848495483
# BoundingBox Regression MAE  : 49.640254974365234
# =======================================================================================
# =======================================================================================
# Epoch 76 Loss: 119.90275231186224
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 49.50649642944336
# =======================================================================================
# =======================================================================================
# Epoch 77 Loss: 79.88646464445154
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 49.2757682800293
# =======================================================================================
# =======================================================================================
# Epoch 78 Loss: 75.0322265625
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 49.2294921875
# =======================================================================================
# =======================================================================================
# Epoch 79 Loss: 76.07743243781887
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 49.36835861206055
# =======================================================================================
# =======================================================================================
# Epoch 80 Loss: 66.77122528698979
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 49.300682067871094
# =======================================================================================
# =======================================================================================
# Epoch 81 Loss: 106.53234614158163
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 49.30530548095703
# =======================================================================================
# =======================================================================================
# Epoch 82 Loss: 78.1096490353954
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 49.569610595703125
# =======================================================================================
# =======================================================================================
# Epoch 83 Loss: 130.27865911989795
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 49.5765495300293
# =======================================================================================
# =======================================================================================
# Epoch 84 Loss: 114.52211216517857
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 49.461429595947266
# =======================================================================================
# =======================================================================================
# Epoch 85 Loss: 84.89378388073979
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 49.41587448120117
# =======================================================================================
# =======================================================================================
# Epoch 86 Loss: 78.46732999840562
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 49.46023941040039
# =======================================================================================
# =======================================================================================
# Epoch 87 Loss: 76.52196269132654
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 49.52238082885742
# =======================================================================================
# =======================================================================================
# Epoch 88 Loss: 138.80867346938774
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 49.55392074584961
# =======================================================================================
# =======================================================================================
# Epoch 89 Loss: 82.02680066167092
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 49.17311096191406
# =======================================================================================
# =======================================================================================
# Epoch 90 Loss: 78.11869220344387
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 49.1425666809082
# =======================================================================================
# =======================================================================================
# Epoch 91 Loss: 62.90770986128827
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 49.413673400878906
# =======================================================================================
# =======================================================================================
# Epoch 92 Loss: 186.7431042729592
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 49.44575119018555
# =======================================================================================
# =======================================================================================
# Epoch 93 Loss: 127.08478156887755
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 49.30824661254883
# =======================================================================================
# =======================================================================================
# Epoch 94 Loss: 63.90800382653061
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 49.17692184448242
# =======================================================================================
# =======================================================================================
# Epoch 95 Loss: 97.49920280612245
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 49.22556686401367
# =======================================================================================
# =======================================================================================
# Epoch 96 Loss: 71.90183055644133
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9775510430335999
# BoundingBox Regression MAE  : 48.99861526489258
# =======================================================================================
# =======================================================================================
# Epoch 97 Loss: 172.4109335140306
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9714285731315613
# BoundingBox Regression MAE  : 49.01352310180664
# =======================================================================================
# =======================================================================================
# Epoch 98 Loss: 139.73246173469389
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.981632649898529
# BoundingBox Regression MAE  : 49.200096130371094
# =======================================================================================
# =======================================================================================
# Epoch 99 Loss: 124.59679926658163
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9727891087532043
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 49.28642654418945
# =======================================================================================
# =======================================================================================

# %%
train(num_epochs,train_list, val_list, batch_size, device,'FinalBest_model.pth')
# Out:
# Epoch 0 Loss: 102.45473931760205
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9693877696990967
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 49.358070373535156
# =======================================================================================
# =======================================================================================
# Epoch 1 Loss: 67.70049924266581
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9826530814170837
# BoundingBox Regression MAE  : 49.074737548828125
# =======================================================================================
# =======================================================================================
# Epoch 2 Loss: 82.12059052136479
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 49.16376876831055
# =======================================================================================
# =======================================================================================
# Epoch 3 Loss: 121.69243263711735
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 49.41157150268555
# =======================================================================================
# =======================================================================================
# Epoch 4 Loss: 61.43328483737245
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 49.254608154296875
# =======================================================================================
# =======================================================================================
# Epoch 5 Loss: 112.28604312818878
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 49.25934600830078
# =======================================================================================
# =======================================================================================
# Epoch 6 Loss: 75.38359474649235
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9846938848495483
# BoundingBox Regression MAE  : 49.16706848144531
# =======================================================================================
# =======================================================================================
# Epoch 7 Loss: 220.73875956632654
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 49.0430793762207
# =======================================================================================
# =======================================================================================
# Epoch 8 Loss: 142.0689772002551
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.981632649898529
# BoundingBox Regression MAE  : 49.00008010864258
# =======================================================================================
# =======================================================================================
# Epoch 9 Loss: 92.95968191964286
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 49.07302474975586
# =======================================================================================
# =======================================================================================
# Epoch 10 Loss: 63.148367745535715
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 49.099578857421875
# =======================================================================================
# =======================================================================================
# Epoch 11 Loss: 56.61653977997449
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9806122183799744
# BoundingBox Regression MAE  : 49.35818862915039
# =======================================================================================
# =======================================================================================
# Epoch 12 Loss: 171.73608896683675
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 49.6036262512207
# =======================================================================================
# =======================================================================================
# Epoch 13 Loss: 86.77745336415816
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9826530814170837
# BoundingBox Regression MAE  : 49.14548110961914
# =======================================================================================
# =======================================================================================
# Epoch 14 Loss: 138.31431361607142
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 49.01437759399414
# =======================================================================================
# =======================================================================================
# Epoch 15 Loss: 76.03262017697705
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 49.011817932128906
# =======================================================================================
# =======================================================================================
# Epoch 16 Loss: 82.53403021364795
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 48.93271255493164
# =======================================================================================
# =======================================================================================
# Epoch 17 Loss: 71.52312360491071
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 48.82184600830078
# =======================================================================================
# =======================================================================================
# Epoch 18 Loss: 69.19869559151786
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 48.87432861328125
# =======================================================================================
# =======================================================================================
# Epoch 19 Loss: 109.6771464445153
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 49.1728630065918
# =======================================================================================
# =======================================================================================
# Epoch 20 Loss: 125.04942602040816
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.976190447807312
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 49.24095153808594
# =======================================================================================
# =======================================================================================
# Epoch 21 Loss: 59.386404854910715
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 49.20745086669922
# =======================================================================================
# =======================================================================================
# Epoch 22 Loss: 69.6489556760204
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 48.93180847167969
# =======================================================================================
# =======================================================================================
# Epoch 23 Loss: 83.70417131696429
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 48.78395080566406
# =======================================================================================
# =======================================================================================
# Epoch 24 Loss: 95.49886399872449
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 49.05600357055664
# =======================================================================================
# =======================================================================================
# Epoch 25 Loss: 91.8267897002551
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9217687249183655
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 49.21214294433594
# =======================================================================================
# =======================================================================================
# Epoch 26 Loss: 62.29170320471939
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9727891087532043
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 49.04706573486328
# =======================================================================================
# =======================================================================================
# Epoch 27 Loss: 77.43277164381378
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 48.96223831176758
# =======================================================================================
# =======================================================================================
# Epoch 28 Loss: 98.25521165497449
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 48.7928581237793
# =======================================================================================
# =======================================================================================
# Epoch 29 Loss: 70.59376992984694
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 48.73206329345703
# =======================================================================================
# =======================================================================================
# Epoch 30 Loss: 64.37330596301021
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 48.93253707885742
# =======================================================================================
# =======================================================================================
# Epoch 31 Loss: 68.70184948979592
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9727891087532043
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 49.21160125732422
# =======================================================================================
# =======================================================================================
# Epoch 32 Loss: 68.57999840561224
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9625850319862366
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 49.12289810180664
# =======================================================================================
# =======================================================================================
# Epoch 33 Loss: 73.54509127869898
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 48.95109558105469
# =======================================================================================
# =======================================================================================
# Epoch 34 Loss: 67.07425362723214
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 48.657466888427734
# =======================================================================================
# =======================================================================================
# Epoch 35 Loss: 117.90572185905613
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 48.58952331542969
# =======================================================================================
# =======================================================================================
# Epoch 36 Loss: 114.03765744579081
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9928571581840515
# BoundingBox Regression MAE  : 48.960357666015625
# =======================================================================================
# =======================================================================================
# Epoch 37 Loss: 81.45043447066327
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9829931855201721
# Species Classification Score: 0.9928571581840515
# BoundingBox Regression MAE  : 49.09730911254883
# =======================================================================================
# =======================================================================================
# Epoch 38 Loss: 60.38281748246173
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 49.09271240234375
# =======================================================================================
# =======================================================================================
# Epoch 39 Loss: 65.5862115353954
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9928571581840515
# BoundingBox Regression MAE  : 49.001678466796875
# =======================================================================================
# =======================================================================================
# Epoch 40 Loss: 107.24917291135205
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9836734533309937
# BoundingBox Regression MAE  : 49.009124755859375
# =======================================================================================
# =======================================================================================
# Epoch 41 Loss: 86.46744459502551
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 48.821571350097656
# =======================================================================================
# =======================================================================================
# Epoch 42 Loss: 70.21053890306122
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 48.94528579711914
# =======================================================================================
# =======================================================================================
# Epoch 43 Loss: 64.24779276945154
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 48.552001953125
# =======================================================================================
# =======================================================================================
# Epoch 44 Loss: 56.927021882971935
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9928571581840515
# BoundingBox Regression MAE  : 48.761863708496094
# =======================================================================================
# =======================================================================================
# Epoch 45 Loss: 73.95160036670919
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9928571581840515
# BoundingBox Regression MAE  : 48.805572509765625
# =======================================================================================
# =======================================================================================
# Epoch 46 Loss: 64.45544682716837
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 48.57965850830078
# =======================================================================================
# =======================================================================================
# Epoch 47 Loss: 56.25836555325255
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 48.466163635253906
# =======================================================================================
# =======================================================================================
# Epoch 48 Loss: 140.7958984375
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 48.357749938964844
# =======================================================================================
# =======================================================================================
# Epoch 49 Loss: 88.30132932079081
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 48.448875427246094
# =======================================================================================
# =======================================================================================
# Epoch 50 Loss: 56.39654416454081
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 48.706214904785156
# =======================================================================================
# =======================================================================================
# Epoch 51 Loss: 56.620246731505105
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 49.19968795776367
# =======================================================================================
# =======================================================================================
# Epoch 52 Loss: 63.40791912468112
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 49.42983627319336
# =======================================================================================
# =======================================================================================
# Epoch 53 Loss: 154.77166374362244
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9928571581840515
# BoundingBox Regression MAE  : 49.092010498046875
# =======================================================================================
# =======================================================================================
# Epoch 54 Loss: 106.02049784757654
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 48.78770065307617
# =======================================================================================
# =======================================================================================
# Epoch 55 Loss: 63.35658482142857
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 48.75511169433594
# =======================================================================================
# =======================================================================================
# Epoch 56 Loss: 56.766960299744895
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 48.57538986206055
# =======================================================================================
# =======================================================================================
# Epoch 57 Loss: 77.94503348214286
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 48.668941497802734
# =======================================================================================
# =======================================================================================
# Epoch 58 Loss: 162.30558434311226
# Object Detection Score      : 0.9387755393981934
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 48.973636627197266
# =======================================================================================
# =======================================================================================
# Epoch 59 Loss: 67.55728834502551
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 48.89865493774414
# =======================================================================================
# =======================================================================================
# Epoch 60 Loss: 119.9604791135204
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 48.49526596069336
# =======================================================================================
# =======================================================================================
# Epoch 61 Loss: 71.56929109534438
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 48.327457427978516
# =======================================================================================
# =======================================================================================
# Epoch 62 Loss: 73.71533701371173
# Object Detection Score      : 0.9489796161651611
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 48.618988037109375
# =======================================================================================
# =======================================================================================
# Epoch 63 Loss: 72.70481405452806
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9795918464660645
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 48.583045959472656
# =======================================================================================
# =======================================================================================
# Epoch 64 Loss: 53.208027742346935
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 48.520782470703125
# =======================================================================================
# =======================================================================================
# Epoch 65 Loss: 65.20059390943878
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.981632649898529
# BoundingBox Regression MAE  : 48.37130355834961
# =======================================================================================
# =======================================================================================
# Epoch 66 Loss: 75.24486806441327
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 48.35064697265625
# =======================================================================================
# =======================================================================================
# Epoch 67 Loss: 145.78045280612244
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 48.61821365356445
# =======================================================================================
# =======================================================================================
# Epoch 68 Loss: 130.2442402742347
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9795918464660645
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 48.60285949707031
# =======================================================================================
# =======================================================================================
# Epoch 69 Loss: 180.61619100765307
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9795918464660645
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 48.75621795654297
# =======================================================================================
# =======================================================================================
# Epoch 70 Loss: 65.2197564572704
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9863945841789246
# Species Classification Score: 0.9867346882820129
# BoundingBox Regression MAE  : 48.54874801635742
# =======================================================================================
# =======================================================================================
# Epoch 71 Loss: 118.59871253188776
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 48.44484329223633
# =======================================================================================
# =======================================================================================
# Epoch 72 Loss: 67.52237623565051
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 48.40598678588867
# =======================================================================================
# =======================================================================================
# Epoch 73 Loss: 94.89229910714286
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9846938848495483
# BoundingBox Regression MAE  : 48.226524353027344
# =======================================================================================
# =======================================================================================
# Epoch 74 Loss: 61.19321986607143
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9857142567634583
# BoundingBox Regression MAE  : 48.222537994384766
# =======================================================================================
# =======================================================================================
# Epoch 75 Loss: 78.7359394929847
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9846938848495483
# BoundingBox Regression MAE  : 48.344398498535156
# =======================================================================================
# =======================================================================================
# Epoch 76 Loss: 63.232596261160715
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 48.584232330322266
# =======================================================================================
# =======================================================================================
# Epoch 77 Loss: 84.26180843431122
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 48.526737213134766
# =======================================================================================
# =======================================================================================
# Epoch 78 Loss: 89.29203204719387
# Object Detection Score      : 0.954081654548645
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9897959232330322
# BoundingBox Regression MAE  : 48.789588928222656
# =======================================================================================
# =======================================================================================
# Epoch 79 Loss: 78.53790656887755
# Object Detection Score      : 0.9591836929321289
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9928571581840515
# BoundingBox Regression MAE  : 48.63508605957031
# =======================================================================================
# =======================================================================================
# Epoch 80 Loss: 62.37534877232143
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9928571581840515
# BoundingBox Regression MAE  : 48.31233215332031
# =======================================================================================
# =======================================================================================
# Epoch 81 Loss: 110.1654276945153
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9928571581840515
# BoundingBox Regression MAE  : 48.269493103027344
# =======================================================================================
# =======================================================================================
# Epoch 82 Loss: 106.05082110969387
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 48.164794921875
# =======================================================================================
# =======================================================================================
# Epoch 83 Loss: 80.814697265625
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9928571581840515
# BoundingBox Regression MAE  : 48.04505157470703
# =======================================================================================
# =======================================================================================
# Epoch 84 Loss: 117.06131417410714
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 48.169105529785156
# =======================================================================================
# =======================================================================================
# Epoch 85 Loss: 92.06034757653062
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 48.044403076171875
# =======================================================================================
# =======================================================================================
# Epoch 86 Loss: 87.97137077487245
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 48.137596130371094
# =======================================================================================
# =======================================================================================
# Epoch 87 Loss: 62.233966438137756
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 48.374900817871094
# =======================================================================================
# =======================================================================================
# Epoch 88 Loss: 106.55223612882654
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9877551198005676
# BoundingBox Regression MAE  : 48.59270477294922
# =======================================================================================
# =======================================================================================
# Epoch 89 Loss: 106.87739158163265
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9887754917144775
# BoundingBox Regression MAE  : 48.306068420410156
# =======================================================================================
# =======================================================================================
# Epoch 90 Loss: 121.72267617984694
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 48.00244140625
# =======================================================================================
# =======================================================================================
# Epoch 91 Loss: 139.92576132015307
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 48.19797134399414
# =======================================================================================
# =======================================================================================
# Epoch 92 Loss: 72.82284359056122
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9908163547515869
# BoundingBox Regression MAE  : 48.336280822753906
# =======================================================================================
# =======================================================================================
# Epoch 93 Loss: 103.21802256058673
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9928571581840515
# BoundingBox Regression MAE  : 48.41622543334961
# =======================================================================================
# =======================================================================================
# Epoch 94 Loss: 99.31171277104592
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9928571581840515
# BoundingBox Regression MAE  : 48.3681526184082
# =======================================================================================
# =======================================================================================
# Epoch 95 Loss: 64.73486328125
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 48.22770690917969
# =======================================================================================
# =======================================================================================
# Epoch 96 Loss: 66.87926000478316
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 48.12535858154297
# =======================================================================================
# =======================================================================================
# Epoch 97 Loss: 88.38307158801021
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9918367266654968
# BoundingBox Regression MAE  : 48.10683822631836
# =======================================================================================
# =======================================================================================
# Epoch 98 Loss: 60.52197265625
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9928571581840515
# BoundingBox Regression MAE  : 48.079593658447266
# =======================================================================================
# =======================================================================================
# Epoch 99 Loss: 58.55473732461735
# Object Detection Score      : 0.9438775777816772
# Cat_Dog Classification Score: 0.9897959232330322
# Species Classification Score: 0.9928571581840515
# BoundingBox Regression MAE  : 48.05431365966797
# =======================================================================================
# =======================================================================================

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cp /content/FinalBest_model.pth /content/drive/MyDrive/ML_Engineer_MTailor_Assessment

# %%
import os
import random
import shutil

def copy_random_files(source_folder, destination_folder, num_files):
    file_list = os.listdir(source_folder)
    random_files = random.sample(file_list, num_files)
    if not os.path.exists(destination_folder):
      os.makedirs(destination_folder)
    
    for file_name in random_files:
        source_path = os.path.join(source_folder, file_name)
        destination_path = os.path.join(destination_folder, file_name)
        shutil.copy2(source_path, destination_path)

# usage:
source_folder = 'assessment_dataset/images'
destination_folder = 'testImgs'
num_files_to_copy = 50

copy_random_files(source_folder, destination_folder, num_files_to_copy)

# %%
from PIL import Image, ImageDraw

def draw_bounding_box(image, bbox,imgName, savePath):
  
    pil_image= image
    
    # Create an ImageDraw object
    draw = ImageDraw.Draw(pil_image)

    # Draw the bounding box rectangle
    draw.rectangle(bbox, outline='red', width=2)

    # Convert the PIL Image back to a numpy array
    image_with_bbox = np.array(pil_image)
    r= Image.fromarray(image_with_bbox)
    r.save(os.path.join(savePath, imgName))
    return

# %%
from PIL import ImageDraw, Image

def visualize(model_weights, image_folder_path, output_folder="output"):
  if not os.path.exists(output_folder):
    os.makedirs(output_folder)
  model = Model()
  model.load_state_dict(torch.load(model_weights))
  model.eval()
  
  transform = transforms.Compose([transforms.Resize((224, 224)),transforms.ToTensor()])
  imgList, pilList=[], []

  image= None
  for imgName in os.listdir(image_folder_path):
      img_path= os.path.join(image_folder_path, imgName)
      image = Image.open(img_path).convert('RGB')
      pilList.append(image)
      image_ = transform(image)
      imgList.append(image_)
  
  imgsBatch= torch.stack(imgList,dim=0)
  outputs = model(imgsBatch)
  # Post-process the outputs
  #Object Output
  pred_object = post_process_object(outputs["object"].squeeze())
  pred_objectList = ["True" if i == 1 else "False" for i in list(pred_object)]
  #Specie Output
  pred_specie = post_process_specie(outputs["specie"])
  pred_specieList = [id2label_specie.get(i.tolist().index(1)) for i in list(pred_specie)]
  #cat_or_dog Output
  pred_cat_or_dog = post_process_cat_or_dog(outputs["cat_or_dog"])
  pred_cat_or_dogList = [id2label_catDog.get(i.tolist().index(1)) for i in list(pred_cat_or_dog)]
  #bbox Output
  pred_bbox = post_process_bbox(outputs["bbox"])

  tupList= list(zip(pred_objectList,pred_cat_or_dogList, pred_specieList, pred_bbox.detach().numpy().tolist()))
  dictList={}
  for i, tup in enumerate(tupList):
    obj, cat_dog, specie, bbox= tup
    if obj =='True':
      dictList[os.listdir(image_folder_path)[i]]= { "has_object": True, "cat_or_dog": cat_dog, "specie": specie, "xmin": bbox[0], "ymin": bbox[1], "xmax": bbox[2], "ymax": bbox[3] }
      draw_bounding_box(pilList[i], bbox,os.listdir(image_folder_path)[i], output_folder) 

    else:
      dictList[os.listdir(image_folder_path)[i]]= { "has_object": False, "cat_or_dog": 'NA', "specie": "NA", "xmin": 0, "ymin": 0, "xmax": 0, "ymax": 0 } 
      pilList[i].save(os.path.join(output_folder, os.listdir(image_folder_path)[i]))
  return dictList

# %%
dict_=visualize('FinalBest_model.pth', 'testImgs', output_folder="output")

# %%
dict_
# Out:
# {'Birman_118.jpg': {'has_object': True,
#   'cat_or_dog': 'cat',
#   'specie': 'Birman',
#   'xmin': 96.17841339111328,
#   'ymin': 42.844608306884766,
#   'xmax': 225.34681701660156,
#   'ymax': 166.86224365234375},
#  'beagle_182.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'beagle',
#   'xmin': 118.74986267089844,
#   'ymin': 51.49817657470703,
#   'xmax': 296.9421691894531,
#   'ymax': 225.2675323486328},
#  'Persian_140.jpg': {'has_object': True,
#   'cat_or_dog': 'cat',
#   'specie': 'Persian',
#   'xmin': 138.2572479248047,
#   'ymin': 62.0803337097168,
#   'xmax': 338.28802490234375,
#   'ymax': 252.29116821289062},
#  'Birman_113.jpg': {'has_object': True,
#   'cat_or_dog': 'cat',
#   'specie': 'Birman',
#   'xmin': 139.99917602539062,
#   'ymin': 63.98301315307617,
#   'xmax': 330.376953125,
#   'ymax': 245.40370178222656},
#  'Abyssinian_144.jpg': {'has_object': True,
#   'cat_or_dog': 'cat',
#   'specie': 'Abyssinian',
#   'xmin': 123.70829010009766,
#   'ymin': 53.8429069519043,
#   'xmax': 304.701171875,
#   'ymax': 227.61920166015625},
#  'chihuahua_176.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'chihuahua',
#   'xmin': 106.1560287475586,
#   'ymin': 47.826351165771484,
#   'xmax': 241.88763427734375,
#   'ymax': 177.32669067382812},
#  'beagle_166.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'beagle',
#   'xmin': 132.6323699951172,
#   'ymin': 55.77323913574219,
#   'xmax': 323.01104736328125,
#   'ymax': 242.3999786376953},
#  'american_pit_bull_terrier_189.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'american_pit_bull_terrier',
#   'xmin': 76.93938446044922,
#   'ymin': 30.0975399017334,
#   'xmax': 174.02471923828125,
#   'ymax': 124.68597412109375},
#  'pomeranian_100.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'pomeranian',
#   'xmin': 110.48033905029297,
#   'ymin': 48.6505241394043,
#   'xmax': 244.44061279296875,
#   'ymax': 177.35975646972656},
#  'Persian_104.jpg': {'has_object': True,
#   'cat_or_dog': 'cat',
#   'specie': 'Persian',
#   'xmin': 129.3994598388672,
#   'ymin': 62.05494689941406,
#   'xmax': 307.6775817871094,
#   'ymax': 229.45645141601562},
#  'n02033041_dowitcher.jpeg': {'has_object': False,
#   'cat_or_dog': 'NA',
#   'specie': 'NA',
#   'xmin': 0,
#   'ymin': 0,
#   'xmax': 0,
#   'ymax': 0},
#  'chihuahua_131.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'chihuahua',
#   'xmin': 63.5327262878418,
#   'ymin': 29.75208854675293,
#   'xmax': 132.748046875,
#   'ymax': 95.00659942626953},
#  'beagle_148.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'beagle',
#   'xmin': 101.83153533935547,
#   'ymin': 42.26183319091797,
#   'xmax': 257.67852783203125,
#   'ymax': 194.90176391601562},
#  'pomeranian_182.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'pomeranian',
#   'xmin': 93.14715576171875,
#   'ymin': 41.56623840332031,
#   'xmax': 217.1335906982422,
#   'ymax': 159.98562622070312},
#  'american_pit_bull_terrier_109.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'american_pit_bull_terrier',
#   'xmin': 99.09778594970703,
#   'ymin': 42.386600494384766,
#   'xmax': 237.0013427734375,
#   'ymax': 176.5707550048828},
#  'american_pit_bull_terrier_150.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'american_pit_bull_terrier',
#   'xmin': 45.4606819152832,
#   'ymin': 21.159608840942383,
#   'xmax': 103.5999755859375,
#   'ymax': 76.92021942138672},
#  'basset_hound_165.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'basset_hound',
#   'xmin': 131.7227783203125,
#   'ymin': 55.28290557861328,
#   'xmax': 338.7912292480469,
#   'ymax': 258.40496826171875},
#  'american_bulldog_201.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'american_bulldog',
#   'xmin': 137.3079833984375,
#   'ymin': 57.34699249267578,
#   'xmax': 361.25164794921875,
#   'ymax': 276.05181884765625},
#  'american_pit_bull_terrier_149.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'american_pit_bull_terrier',
#   'xmin': 94.38031005859375,
#   'ymin': 37.64559555053711,
#   'xmax': 246.41590881347656,
#   'ymax': 187.6719970703125},
#  'basset_hound_118.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'basset_hound',
#   'xmin': 123.7646484375,
#   'ymin': 52.89605712890625,
#   'xmax': 327.7664489746094,
#   'ymax': 251.12709045410156},
#  'chihuahua_147.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'chihuahua',
#   'xmin': 98.9183349609375,
#   'ymin': 43.604156494140625,
#   'xmax': 221.487548828125,
#   'ymax': 160.95469665527344},
#  '1.jpeg': {'has_object': False,
#   'cat_or_dog': 'NA',
#   'specie': 'NA',
#   'xmin': 0,
#   'ymin': 0,
#   'xmax': 0,
#   'ymax': 0},
#  'beagle_144.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'beagle',
#   'xmin': 150.35354614257812,
#   'ymin': 62.415122985839844,
#   'xmax': 393.3739929199219,
#   'ymax': 297.9951477050781},
#  'pomeranian_143.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'pomeranian',
#   'xmin': 66.85997009277344,
#   'ymin': 29.228761672973633,
#   'xmax': 136.68927001953125,
#   'ymax': 96.3847427368164},
#  'basset_hound_16.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'basset_hound',
#   'xmin': 135.74867248535156,
#   'ymin': 65.82451629638672,
#   'xmax': 353.1678161621094,
#   'ymax': 272.5461120605469},
#  'chihuahua_141.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'chihuahua',
#   'xmin': 76.04751586914062,
#   'ymin': 33.841285705566406,
#   'xmax': 188.121337890625,
#   'ymax': 142.31124877929688},
#  'american_bulldog_147.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'american_bulldog',
#   'xmin': 126.6843490600586,
#   'ymin': 57.264739990234375,
#   'xmax': 295.2051086425781,
#   'ymax': 219.58529663085938},
#  'Persian_101.jpg': {'has_object': True,
#   'cat_or_dog': 'cat',
#   'specie': 'Persian',
#   'xmin': 142.07606506347656,
#   'ymin': 60.84147262573242,
#   'xmax': 340.62445068359375,
#   'ymax': 251.57101440429688},
#  'beagle_117.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'beagle',
#   'xmin': 102.52691650390625,
#   'ymin': 45.733489990234375,
#   'xmax': 261.6126708984375,
#   'ymax': 199.05735778808594},
#  'Abyssinian_176.jpg': {'has_object': True,
#   'cat_or_dog': 'cat',
#   'specie': 'Abyssinian',
#   'xmin': 111.83430480957031,
#   'ymin': 48.81852340698242,
#   'xmax': 278.40789794921875,
#   'ymax': 209.13307189941406},
#  'Abyssinian_15.jpg': {'has_object': True,
#   'cat_or_dog': 'cat',
#   'specie': 'Abyssinian',
#   'xmin': 145.36526489257812,
#   'ymin': 60.884483337402344,
#   'xmax': 384.10516357421875,
#   'ymax': 291.97021484375},
#  'american_bulldog_148.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'american_bulldog',
#   'xmin': 118.89849853515625,
#   'ymin': 57.46697998046875,
#   'xmax': 310.71875,
#   'ymax': 239.2362060546875},
#  'Persian_193.jpg': {'has_object': True,
#   'cat_or_dog': 'cat',
#   'specie': 'Persian',
#   'xmin': 141.99659729003906,
#   'ymin': 60.711265563964844,
#   'xmax': 348.0331726074219,
#   'ymax': 258.41217041015625},
#  'beagle_177.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'beagle',
#   'xmin': 154.8612518310547,
#   'ymin': 60.40690231323242,
#   'xmax': 407.2734680175781,
#   'ymax': 308.7798156738281},
#  'Persian_206.jpg': {'has_object': True,
#   'cat_or_dog': 'cat',
#   'specie': 'Persian',
#   'xmin': 131.6371307373047,
#   'ymin': 52.55917739868164,
#   'xmax': 312.36456298828125,
#   'ymax': 228.51470947265625},
#  'Birman_126.jpg': {'has_object': True,
#   'cat_or_dog': 'cat',
#   'specie': 'Birman',
#   'xmin': 139.85089111328125,
#   'ymin': 66.40044403076172,
#   'xmax': 320.8963928222656,
#   'ymax': 236.85711669921875},
#  'basset_hound_125.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'basset_hound',
#   'xmin': 145.12030029296875,
#   'ymin': 61.54765701293945,
#   'xmax': 373.4787292480469,
#   'ymax': 283.8243713378906},
#  'chihuahua_16.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'chihuahua',
#   'xmin': 146.52272033691406,
#   'ymin': 61.38898468017578,
#   'xmax': 363.8913879394531,
#   'ymax': 271.2881164550781},
#  'n01847000_drake.jpeg': {'has_object': False,
#   'cat_or_dog': 'NA',
#   'specie': 'NA',
#   'xmin': 0,
#   'ymin': 0,
#   'xmax': 0,
#   'ymax': 0},
#  'Abyssinian_105.jpg': {'has_object': True,
#   'cat_or_dog': 'cat',
#   'specie': 'Abyssinian',
#   'xmin': 134.6372833251953,
#   'ymin': 62.1176643371582,
#   'xmax': 328.6408996582031,
#   'ymax': 246.2317657470703},
#  'n01877812_wallaby.jpeg': {'has_object': False,
#   'cat_or_dog': 'NA',
#   'specie': 'NA',
#   'xmin': 0,
#   'ymin': 0,
#   'xmax': 0,
#   'ymax': 0},
#  'chihuahua_140.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'chihuahua',
#   'xmin': 108.14859008789062,
#   'ymin': 49.527870178222656,
#   'xmax': 239.25743103027344,
#   'ymax': 173.9058380126953},
#  'beagle_174.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'beagle',
#   'xmin': 109.23834228515625,
#   'ymin': 45.90505599975586,
#   'xmax': 268.1099548339844,
#   'ymax': 201.69493103027344},
#  'basset_hound_105.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'basset_hound',
#   'xmin': 122.14131927490234,
#   'ymin': 50.380489349365234,
#   'xmax': 332.2510681152344,
#   'ymax': 257.9131164550781},
#  'american_pit_bull_terrier_113.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'american_pit_bull_terrier',
#   'xmin': 57.617984771728516,
#   'ymin': 24.900278091430664,
#   'xmax': 133.13104248046875,
#   'ymax': 98.14593505859375},
#  'pomeranian_170.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'pomeranian',
#   'xmin': 98.69843292236328,
#   'ymin': 44.42402648925781,
#   'xmax': 224.47010803222656,
#   'ymax': 164.42823791503906},
#  'Abyssinian_160.jpg': {'has_object': True,
#   'cat_or_dog': 'cat',
#   'specie': 'Abyssinian',
#   'xmin': 119.76390075683594,
#   'ymin': 50.05206298828125,
#   'xmax': 274.21832275390625,
#   'ymax': 200.23162841796875},
#  'n02002724_black_stork.jpeg': {'has_object': False,
#   'cat_or_dog': 'NA',
#   'specie': 'NA',
#   'xmin': 0,
#   'ymin': 0,
#   'xmax': 0,
#   'ymax': 0},
#  'Persian_191.jpg': {'has_object': True,
#   'cat_or_dog': 'cat',
#   'specie': 'Persian',
#   'xmin': 157.0125732421875,
#   'ymin': 70.40045166015625,
#   'xmax': 367.8904724121094,
#   'ymax': 271.4191589355469},
#  'basset_hound_149.jpg': {'has_object': True,
#   'cat_or_dog': 'dog',
#   'specie': 'basset_hound',
#   'xmin': 119.87311553955078,
#   'ymin': 53.459510803222656,
#   'xmax': 305.2425231933594,
#   'ymax': 233.8625030517578}}
